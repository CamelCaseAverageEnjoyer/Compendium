# %%
from PIL import Image, ImageOps, ImageEnhance
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
im = Image.open(f"local/videos/cam3_calibrate_checkboard/5519.jpg")

# %%
fig = plt.figure(figsize=(13, 20))
plt.imshow(im, cmap='gray')

x = [ 470,  488, 1428, 1450,  800,  800,  800,  800]
y = [1410, 1410, 1380, 1380, 1245, 1280, 2485, 2593]

размер_А4 = [210, 297]
размер_ячейки = размер_А4[0] * (x[2]-x[1]) / (x[3]-x[0]) / 7
print(f"Размер ячейки: {размер_ячейки:.1f} мм")
размер_ячейки = размер_А4[1] * (y[2+4]-y[1+4]) / (y[3+4]-y[0+4]) / 9
print(f"Размер ячейки: {размер_ячейки:.1f} мм")

plt.scatter(x, y, 10, 'r')
plt.show()
